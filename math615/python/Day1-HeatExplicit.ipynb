# %%
import matplotlib.pyplot as pp;
pp.rcParams['figure.figsize'] = [10, 5]

# %%
# %run heatbasic.py

# %%
validate(1,10,300)

# %%
validate(2,10,300)

# %%
validate(3,10,300)

# %%
validate(3,20,300)

# %%
plot_run(10,20)
# Out:
# mu=0.500000

# %%
plot_run(100,20)
# Out:
# mu=50.000000

# %%
plot_run(20,20)
# Out:
# mu=2.000000

# %%
plot_run(12,20)
# Out:
# mu=0.720000

# %%
plot_run(11,20)
# Out:
# mu=0.605000

# %%
plot_run(11,25)
# Out:
# mu=0.484000

# %%
plot_run(100,2000)
# Out:
# mu=0.500000

# %%
plot_run(110,2000)
# Out:
# mu=0.605000
